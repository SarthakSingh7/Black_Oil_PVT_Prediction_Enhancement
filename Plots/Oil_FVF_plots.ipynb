# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df_Amokura_1 
df1 = pd.read_excel(r"C:\Users\sarth\OneDrive\Documents\My Projects\Project2_sem7\Plots_for_literature\Oil_FVF plots.xlsx", sheet_name = 'Amokura-1')
#df_Cheal_A3X
df2 = pd.read_excel(r"C:\Users\sarth\OneDrive\Documents\My Projects\Project2_sem7\Plots_for_literature\Oil_FVF plots.xlsx", sheet_name = 'Cheal-A3X')
#df_Goldie_1_BHS 
df3 = pd.read_excel(r"C:\Users\sarth\OneDrive\Documents\My Projects\Project2_sem7\Plots_for_literature\Oil_FVF plots.xlsx", sheet_name = 'Goldie-1_BHS')

# %%
df1
# Out:
#     Pressure_Psia  Oil_FVF  Well_Name
# 0           13015    1.247  Amokura-1
# 1           10990    1.261  Amokura-1
# 2            8999    1.278  Amokura-1
# 3            6994    1.299  Amokura-1
# 4            5999    1.311  Amokura-1
# 5            5262    1.321  Amokura-1
# 6            4996    1.325  Amokura-1
# 7            4508    1.332  Amokura-1
# 8            3997    1.340  Amokura-1
# 9            3598    1.346  Amokura-1
# 10           2998    1.356  Amokura-1
# 11           2503    1.365  Amokura-1
# 12           2006    1.374  Amokura-1
# 13           1704    1.380  Amokura-1
# 14           1602    1.382  Amokura-1
# 15           1505    1.384  Amokura-1
# 16           1215    1.353  Amokura-1
# 17           1015    1.330  Amokura-1
# 18            815    1.307  Amokura-1
# 19            515    1.269  Amokura-1

# %%
df2
# Out:
#     Pressure_Psig  Oil_FVF  Well_Name
# 0            3000   1.2571  Cheal-A3X
# 1            2800   1.2589  Cheal-A3X
# 2            2600   1.2608  Cheal-A3X
# 3            2400   1.2629  Cheal-A3X
# 4            2200   1.2650  Cheal-A3X
# 5            2167   1.2653  Cheal-A3X
# 6            2000   1.2515  Cheal-A3X
# 7            1750   1.2283  Cheal-A3X
# 8            1500   1.2083  Cheal-A3X
# 9            1250   1.1851  Cheal-A3X
# 10           1000   1.1690  Cheal-A3X
# 11            750   1.1486  Cheal-A3X
# 12            500   1.1286  Cheal-A3X
# 13            250   1.0981  Cheal-A3X
# 14             15   1.0287  Cheal-A3X

# %%
df3
# Out:
#     Pressure_Psig  Oil_FVF     Well_Name
# 0            5000   1.1521  Goldie-1_BHS
# 1            4000   1.1593  Goldie-1_BHS
# 2            3000   1.1673  Goldie-1_BHS
# 3            2500   1.1719  Goldie-1_BHS
# 4            2000   1.1770  Goldie-1_BHS
# 5            1775   1.1795  Goldie-1_BHS
# 6            1600   1.1691  Goldie-1_BHS
# 7            1400   1.1547  Goldie-1_BHS
# 8            1200   1.1403  Goldie-1_BHS
# 9            1000   1.1242  Goldie-1_BHS
# 10            800   1.1111  Goldie-1_BHS
# 11            600   1.0972  Goldie-1_BHS
# 12            400   1.0827  Goldie-1_BHS
# 13            200   1.0670  Goldie-1_BHS
# 14              0   1.0351  Goldie-1_BHS

# %%
plt.plot(df1["Pressure_Psia"],df1["Oil_FVF"])

# %%
plt.plot(df2["Pressure_Psig"],df2["Oil_FVF"])

# %%
plt.plot(df3["Pressure_Psig"],df3["Oil_FVF"])

# %%
plt.scatter(df1["Pressure_Psia"],df1["Oil_FVF"])

# %%
plt.scatter(df2["Pressure_Psig"],df2["Oil_FVF"])

# %%
plt.scatter(df3["Pressure_Psig"],df3["Oil_FVF"], color = 'blue')
plt.xlabel('Reservoir Pressure psig')
plt.ylabel('Oil Formation Volume Factor')
# Out:
# Text(0, 0.5, 'Oil Formation Volume Factor')

# %%
plt.figure(figsize = (8,6))
sns.lineplot(x = df3["Pressure_Psig"],y= df3["Oil_FVF"], color = 'blue')
sns.scatterplot(x = df3["Pressure_Psig"],y = df3["Oil_FVF"], color = 'blue', label = "Oil FVF",legend = False)
plt.xlabel('Reservoir Pressure, psig')
plt.ylabel('Oil Formation Volume Factor, rbbl/STB')
plt.title('Goldie-1-BHS, Oil FVF')
plt.axvline(1775, linestyle = "--", color ="red", label = "Bubble point prerssure, Pb = 1775 psia")
plt.legend()

plt.savefig('OIL FVF.png', dpi = 1200, bbox_inches='tight')

# %%
df3["Pressure_Psig"]
# pb = 1775
# Out:
# 0     5000
# 1     4000
# 2     3000
# 3     2500
# 4     2000
# 5     1775
# 6     1600
# 7     1400
# 8     1200
# 9     1000
# 10     800
# 11     600
# 12     400
# 13     200
# 14       0
# Name: Pressure_Psig, dtype: int64

# %%
plt.plot(df3["Pressure_Psig"],df3["Oil_FVF"], color = 'crimson')
plt.xlabel('Reservoir Pressure psig')
plt.ylabel('Oil Formation Volume Factor')
# Out:
# Text(0, 0.5, 'Oil Formation Volume Factor')

# %% [markdown]
# ![image.png](attachment:image.png)
