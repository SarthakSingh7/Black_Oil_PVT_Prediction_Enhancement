# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy

import statsmodels.api as sm

# %%
df = pd.read_excel(r"C:\Users\sarth\OneDrive\Documents\My Projects\Project2_sem7\Plots_for_literature\EDA plots\Training_data_Bo_with_PandVisc_EDA.xlsx")

# %%
df
# Out:
#       P_psia  Rs_SCF/STB  Oil_FVF  Oil_dens_g/cc  Z_factor  Temp_F  gas_spgr  \
# 0    13015.0       440.0    1.247         0.7580     0.000   251.6     0.000
# 1    10990.0       440.0    1.261         0.7500     0.000   251.6     0.000
# 2     8999.0       440.0    1.278         0.7400     0.000   251.6     0.000
# 3     6994.0       440.0    1.299         0.7280     0.000   251.6     0.000
# 4     5999.0       440.0    1.311         0.7210     0.000   251.6     0.000
# ..       ...         ...      ...            ...       ...     ...       ...
# 292    900.0       334.0    1.255         0.7364     0.903   186.8     0.826
# 293    500.0       230.0    1.208         0.7482     0.942   186.8     0.900
# 294    200.0       137.0    1.161         0.7598     0.975   186.8     1.063
# 295     90.0        93.0    1.135         0.7663     0.988   186.8     1.261
# 296      0.0         0.0    1.062         0.7845     1.000   186.8     1.822
#
# ...

# %%
df.describe()
# Out:
#              P_psia   Rs_SCF/STB     Oil_FVF  Oil_dens_g/cc    Z_factor  \
# count    297.000000   297.000000  297.000000     297.000000  297.000000
# mean    1572.797120   373.612388    1.248943       0.745843    0.708320
# std     1604.173692   308.303898    0.165027       0.064878    0.389795
# min        0.000000     0.000000    1.013200       0.614800    0.000000
# 25%      500.000000   154.000000    1.119000       0.700600    0.803000
# 50%     1200.000000   326.000000    1.219000       0.742400    0.896000
# 75%     2200.000000   496.000000    1.343000       0.781200    0.952000
# max    13015.000000  1422.000000    1.837000       0.955300    1.020000
#
#            Temp_F    gas_spgr      Vis_cP  Bubble point
# count  297.000000  297.000000  269.000000          27.0
# mean   167.498182    0.641896    0.772108           1.0
# std     41.702378    0.440097    0.329151           0.0
# min    100.000000    0.000000    0.250000           1.0
# ...

# %%
df.columns
# Out:
# Index(['P_psia', 'Rs_SCF/STB', 'Oil_FVF', 'Oil_dens_g/cc', 'Z_factor',
#        'Temp_F', 'gas_spgr', 'Vis_cP', 'Bubble point', 'Region'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['P_psia', 'Rs_SCF/STB', 'Oil_FVF', 'Oil_dens_g/cc', 'Z_factor',
#        'Temp_F', 'gas_spgr', 'Vis_cP', 'Bubble point', 'Region'],
#       dtype='object')

# %%
fig = plt.figure(figsize = (15,10))


fig.add_subplot(4,2,1)

# residual plots for linear regression
sns.histplot(x = df['P_psia'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'maroon'])
plt.xlabel('Pressure, psia')
plt.ylabel('Count')
plt.title('Measured values of Pressure in psia')
#plt.show()

########################################################

fig.add_subplot(4,2,2)

# residual plots for linear regression
sns.histplot(x = df['Rs_SCF/STB'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'maroon'])
plt.xlabel("Rs Solution gas-oil ratio, SCF/STB")
plt.ylabel('Count')
plt.title('Values of Solution gas-oil ratio in SCF/STB')
#plt.show()

########################################################


########################################################
fig.add_subplot(4,2,3)

# residual plots for linear regression
sns.histplot(x = df['Oil_FVF'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'maroon'])
plt.xlabel('Oil Formation Volume Factor, rbbl/STB')
plt.ylabel('Count')
plt.title('Oil Formation Volume Factor, rbbl/STB')
#plt.show()


########################################################

fig.add_subplot(4,2,4)

# residual plots for linear regression
sns.histplot(x = df['Oil_dens_g/cc'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'maroon'])
plt.xlabel('Oil Density, g/cc')
plt.ylabel('Count')
plt.title('Measured Oil density in g/cc')
#plt.show()


########################################################

fig.add_subplot(4,2,5)

# residual plots for linear regression
sns.histplot(x = df['Z_factor'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'maroon'])
plt.xlabel('Z-Factor')
plt.ylabel('Count')
plt.title('Experimental Gas Deviation Z-Factor')
#plt.show()


########################################################

fig.add_subplot(4,2,6)

# residual plots for linear regression
sns.histplot(x = df['Temp_F'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'maroon'])
plt.xlabel('Temperature, F')
plt.ylabel('Count')
plt.title('Measured Temperature in Fahrenheit')
#plt.show()


########################################################

fig.add_subplot(4,2,7)

# residual plots for linear regression
sns.histplot(x = df['gas_spgr'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'maroon'])
plt.xlabel('Gas specific gravity (air = 1)')
plt.ylabel('Count')
plt.title('Gas Specific Gravity')
#plt.show()

########################################################

fig.add_subplot(4,2,8)

# residual plots for linear regression
sns.histplot(x = df['Vis_cP'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'maroon'])

plt.xlabel('Oil Viscosity, cP')
plt.ylabel('Count')
plt.title('Measured Oil Viscosity in cP')
#plt.show()


#################

fig.suptitle('Univariate histogram plots showing distribution of features', fontsize  = 16)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.12, hspace=0.55)
fig.subplots_adjust(top=0.93)
plt.show()

# %%
fig = plt.figure(figsize = (15,10))


fig.add_subplot(4,2,1)

# residual plots for linear regression
sns.histplot(x = df['P_psia'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Pressure, psia')
plt.ylabel('Count')
plt.title('Measured values of Pressure in psia')
#plt.show()

########################################################

fig.add_subplot(4,2,2)

# residual plots for linear regression
sns.histplot(x = df['Rs_SCF/STB'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel("Rs Solution gas-oil ratio, SCF/STB")
plt.ylabel('Count')
plt.title('Values of Solution gas-oil ratio in SCF/STB')
#plt.show()

########################################################


########################################################
fig.add_subplot(4,2,3)

# residual plots for linear regression
sns.histplot(x = df['Oil_FVF'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Oil Formation Volume Factor, rbbl/STB')
plt.ylabel('Count')
plt.title('Oil Formation Volume Factor, rbbl/STB')
#plt.show()


########################################################

fig.add_subplot(4,2,4)

# residual plots for linear regression
sns.histplot(x = df['Oil_dens_g/cc'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Oil Density, g/cc')
plt.ylabel('Count')
plt.title('Measured Oil density in g/cc')
#plt.show()


########################################################

fig.add_subplot(4,2,5)

# residual plots for linear regression
sns.histplot(x = df['Z_factor'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Z-Factor')
plt.ylabel('Count')
plt.title('Experimental Gas Deviation Z-Factor')
#plt.show()


########################################################

fig.add_subplot(4,2,6)

# residual plots for linear regression
sns.histplot(x = df['Temp_F'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Temperature, F')
plt.ylabel('Count')
plt.title('Measured Temperature in Fahrenheit')
#plt.show()


########################################################

fig.add_subplot(4,2,7)

# residual plots for linear regression
sns.histplot(x = df['gas_spgr'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Gas specific gravity (air = 1)')
plt.ylabel('Count')
plt.title('Gas Specific Gravity')
#plt.show()

########################################################

fig.add_subplot(4,2,8)

# residual plots for linear regression
sns.histplot(x = df['Vis_cP'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])

plt.xlabel('Oil Viscosity, cP')
plt.ylabel('Count')
plt.title('Measured Oil Viscosity in cP')
#plt.show()


#################

fig.suptitle('Univariate histogram plots showing distribution of features', fontsize  = 16)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.12, hspace=0.55)
fig.subplots_adjust(top=0.93)

plt.savefig('Histograms.png', dpi = 1200,  bbox_inches='tight')
plt.show()

# %%
df.head()
# Out:
#     P_psia  Rs_SCF/STB  Oil_FVF  Oil_dens_g/cc  Z_factor  Temp_F  gas_spgr  \
# 0  13015.0       440.0    1.247          0.758       0.0   251.6       0.0
# 1  10990.0       440.0    1.261          0.750       0.0   251.6       0.0
# 2   8999.0       440.0    1.278          0.740       0.0   251.6       0.0
# 3   6994.0       440.0    1.299          0.728       0.0   251.6       0.0
# 4   5999.0       440.0    1.311          0.721       0.0   251.6       0.0
#
#    Vis_cP  Bubble point                 Region
# 0     NaN           NaN  Undersaturated Region
# 1   1.010           NaN  Undersaturated Region
# 2   0.957           NaN  Undersaturated Region
# 3   0.852           NaN  Undersaturated Region
# 4   0.800           NaN  Undersaturated Region

# %%
sns.violinplot(data = df, x = df['P_psia'],y = df['Region'])
# Out:
# <Axes: xlabel='P_psia', ylabel='Region'>

# %%
fig = plt.figure(figsize = (15,10))
color2 = ['lime','aqua']

fig.add_subplot(4,2,1)

# residual plots for linear regression
sns.violinplot(data = df, x = df['P_psia'],y = df['Region'], palette = color2)
#sns.histplot(x = df['P_psia'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Pressure, psia')
plt.ylabel('Phase')
plt.title('Measured values of Pressure in psia')
#plt.show()

########################################################

fig.add_subplot(4,2,2)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Rs_SCF/STB'],y = df['Region'], palette = color2)
#sns.histplot(x = df['Rs_SCF/STB'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel("Rs Solution gas-oil ratio, SCF/STB")
plt.ylabel('Phase')
plt.title('Values of Solution gas-oil ratio in SCF/STB')
#plt.show()

########################################################


########################################################
fig.add_subplot(4,2,3)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Oil_FVF'],y = df['Region'], palette = color2)
#sns.histplot(x = df['Oil_FVF'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Oil Formation Volume Factor, rbbl/STB')
plt.ylabel('Phase')
plt.title('Oil Formation Volume Factor, rbbl/STB')
#plt.show()


########################################################

fig.add_subplot(4,2,4)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Oil_dens_g/cc'],y = df['Region'], palette = color2)
#sns.histplot(x = df['Oil_dens_g/cc'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Oil Density, g/cc')
plt.ylabel('Phase')
plt.title('Measured Oil density in g/cc')
#plt.show()


########################################################

fig.add_subplot(4,2,5)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Z_factor'],  palette = ['aqua'])
#sns.histplot(x = df['Z_factor'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Z-Factor')
plt.ylabel('Phase')
plt.title('Experimental Gas Deviation Z-Factor')
#plt.show()


########################################################

fig.add_subplot(4,2,6)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Temp_F'],y = df['Region'], palette = color2)
#sns.histplot(x = df['Temp_F'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Temperature, F')
plt.ylabel('Phase')
plt.title('Measured Temperature in Fahrenheit')
#plt.show()


########################################################

fig.add_subplot(4,2,7)

# residual plots for linear regression
sns.violinplot(data = df, x = df['gas_spgr'],  palette = ['aqua'] )
#sns.histplot(x = df['gas_spgr'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Gas specific gravity (air = 1)')
plt.ylabel('Phase')
plt.title('Gas Specific Gravity')
#plt.show()

########################################################

fig.add_subplot(4,2,8)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Vis_cP'],y = df['Region'], palette = color2 )
#sns.histplot(x = df['Vis_cP'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Oil Viscosity, cP')
plt.ylabel('Phase')
plt.title('Measured Oil Viscosity in cP')
#plt.show()


#################

fig.suptitle('Univariate Violin plots showing desnity and distribution of features', fontsize  = 16)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.55, hspace=0.55)
fig.subplots_adjust(top=0.93)
plt.show()

# %%
fig = plt.figure(figsize = (15,10))
color2 = ['lime','aqua']

fig.add_subplot(4,2,1)

# residual plots for linear regression
sns.violinplot(data = df, x = df['P_psia'],y = df['Region'], palette = color2)
#sns.histplot(x = df['P_psia'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Pressure, psia')
plt.ylabel('Phase')
plt.title('Measured values of Pressure in psia')
#plt.show()

########################################################

fig.add_subplot(4,2,2)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Rs_SCF/STB'],y = df['Region'], palette = color2)
#sns.histplot(x = df['Rs_SCF/STB'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel("Rs Solution gas-oil ratio, SCF/STB")
plt.ylabel('Phase')
plt.title('Values of Solution gas-oil ratio in SCF/STB')
#plt.show()

########################################################


########################################################
fig.add_subplot(4,2,3)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Oil_FVF'],y = df['Region'], palette = color2)
#sns.histplot(x = df['Oil_FVF'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Oil Formation Volume Factor, rbbl/STB')
plt.ylabel('Phase')
plt.title('Oil Formation Volume Factor, rbbl/STB')
#plt.show()


########################################################

fig.add_subplot(4,2,4)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Oil_dens_g/cc'],y = df['Region'], palette = color2)
#sns.histplot(x = df['Oil_dens_g/cc'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Oil Density, g/cc')
plt.ylabel('Phase')
plt.title('Measured Oil density in g/cc')
#plt.show()


########################################################

fig.add_subplot(4,2,5)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Z_factor'],  palette = ['aqua'])
#sns.histplot(x = df['Z_factor'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Z-Factor')
plt.ylabel('Phase')
plt.title('Experimental Gas Deviation Z-Factor')
#plt.show()


########################################################

fig.add_subplot(4,2,6)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Temp_F'],y = df['Region'], palette = color2)
#sns.histplot(x = df['Temp_F'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Temperature, F')
plt.ylabel('Phase')
plt.title('Measured Temperature in Fahrenheit')
#plt.show()


########################################################

fig.add_subplot(4,2,7)

# residual plots for linear regression
sns.violinplot(data = df, x = df['gas_spgr'],  palette = ['aqua'] )
#sns.histplot(x = df['gas_spgr'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Gas specific gravity (air = 1)')
plt.ylabel('Phase')
plt.title('Gas Specific Gravity')
#plt.show()

########################################################

fig.add_subplot(4,2,8)

# residual plots for linear regression
sns.violinplot(data = df, x = df['Vis_cP'],y = df['Region'], palette = color2 )
#sns.histplot(x = df['Vis_cP'], stat = 'count',element = "step", kde = True, hue = df['Region'], palette = ['blue', 'red'])
plt.xlabel('Oil Viscosity, cP')
plt.ylabel('Phase')
plt.title('Measured Oil Viscosity in cP')
#plt.show()


#################

fig.suptitle('Univariate Violin plots showing desnity and distribution of features', fontsize  = 16)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.55, hspace=0.55)
fig.subplots_adjust(top=0.93)
plt.show()

# %%
df.columns
# Out:
# Index(['P_psia', 'Rs_SCF/STB', 'Oil_FVF', 'Oil_dens_g/cc', 'Z_factor',
#        'Temp_F', 'gas_spgr', 'Vis_cP', 'Bubble point', 'Region'],
#       dtype='object')

# %%
# fig = plt.figure(figsize = (30,20))


# fig.add_subplot(4,2,1)
# sm.qqplot(df['P_psia'], line='45')

# fig.add_subplot(4,2,2)
# sm.qqplot(df['Rs_SCF/STB'], line='45')

# fig.add_subplot(4,2,3)
# sm.qqplot(df['Oil_FVF'], line='45')

# fig.add_subplot(4,2,4)
# sm.qqplot(df['Oil_dens_g/cc'], line='45')

# fig.add_subplot(4,2,5)
# sm.qqplot(df['Z_factor'], line='45')

# fig.add_subplot(4,2,6)
# sm.qqplot(df['Temp_F'], line='45')

# fig.add_subplot(4,2,7)
# sm.qqplot(df['gas_spgr'], line='45')

# fig.add_subplot(4,2,8)
# sm.qqplot(df['Vis_cP'], line='45')

# plt.show()

# %%
sm.qqplot(df['P_psia'], line='45',dist = scipy.stats.norm)
plt.show()

# %%
sm.qqplot(df['Rs_SCF/STB'], line='45', dist = scipy.stats.uniform)
plt.show()

# %%
sm.qqplot(df['Oil_FVF'], line='45', dist = scipy.stats.norm)
plt.show()

# %%
sm.qqplot(df['Oil_dens_g/cc'], line='45')
plt.show()

# %%
sm.qqplot(df['Z_factor'], line='45', dist = scipy.stats.uniform)
plt.show()

# %%
sm.qqplot(df['Temp_F'], line='45', dist = scipy.stats.norm)
plt.show()

# %%
sm.qqplot(df['gas_spgr'], line='45')
plt.show()

# %%
sm.qqplot(df['Vis_cP'], line='45')
plt.show()
